# %% [markdown]
# # Grid Up — EDA ve Baseline Şablonu
#
# Bu notebook veri geldiğinde ilk 6 saatlik keşif ve baseline akışı için hazırlanmıştır.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 200)

# %% [markdown]
# ## 1. Dosyaları yükle

# %%
DATA_DIR = Path("../data/raw")
# train = pd.read_csv(DATA_DIR / "train.csv")
# test = pd.read_csv(DATA_DIR / "test.csv")
# sample_submission = pd.read_csv(DATA_DIR / "sample_submission.csv")

# %% [markdown]
# ## 2. Şema ve kalite kontrolleri

# %%
# display(train.head())
# display(train.dtypes.to_frame("dtype"))
# display(train.isna().mean().sort_values(ascending=False).head(30))
# print("Train shape:", train.shape, "Test shape:", test.shape)

# %% [markdown]
# ## 3. Train–test farkları

# %%
# train_only = sorted(set(train.columns) - set(test.columns))
# test_only = sorted(set(test.columns) - set(train.columns))
# print("Sadece train:", train_only)
# print("Sadece test:", test_only)

# %% [markdown]
# ## 4. Validasyon hipotezi
#
# - Zaman bağımlılığı var mı?
# - Aynı varlık birden fazla satırda mı?
# - Test geleceği mi temsil ediyor?
# - Hangi split gerçek kullanım senaryosuna en yakın?

# %% [markdown]
# ## 5. Baseline
#
# Komut satırındaki `python -m src.train` akışıyla ilk OOF ve submission üretimini yapın.
