# %% [markdown]
# # Model Improvement Lab
# Compare the baseline and diagnosis-driven CatBoost on identical time folds.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.model_improvement import run_model_improvement

# %%
artifacts = run_model_improvement(output_root=PROJECT_ROOT, iterations=350)
artifacts
