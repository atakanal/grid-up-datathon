# %% [markdown]
# # Grid Up Ablation Lab
# Run the same-fold ablation and inspect which component created the gain.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.ablation import run_ablation
artifacts = run_ablation(PROJECT_ROOT)
artifacts

# %%
import pandas as pd
pd.read_csv(artifacts.results_path).sort_values('rmse')
