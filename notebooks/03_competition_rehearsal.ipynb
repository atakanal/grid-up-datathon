# %% [markdown]
# # Grid Up Competition Rehearsal
# Bu notebook, komut satırı provasının ürettiği sonuçları incelemek içindir.

# %%
import pandas as pd
from pathlib import Path

results = pd.read_csv(Path('../experiments/rehearsal_results.csv'))
results

# %%
oof = pd.read_csv(Path('../data/processed/rehearsal_oof.csv'))
oof[oof['is_validated']].head()

# %%
importance = pd.read_csv(Path('../experiments/rehearsal_feature_importance.csv'))
importance.head(20)

# %%
submission = pd.read_csv(Path('../submissions/rehearsal_baseline.csv'))
submission.describe(include='all')
