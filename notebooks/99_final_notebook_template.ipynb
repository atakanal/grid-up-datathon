# %% [markdown]
# # Grid Up — Final Notebook Şablonu

# %% [markdown]
# ## Yönetici özeti
# Problemi, çözümü, CV skorunu ve operasyonel değeri 5–7 cümlede özetleyin.

# %% [markdown]
# ## Veri ve problem tanımı

# %% [markdown]
# ## Veri kalitesi ve önemli keşifler

# %% [markdown]
# ## Validasyon tasarımı ve leakage önlemleri

# %% [markdown]
# ## Özellik mühendisliği

# %% [markdown]
# ## Model karşılaştırmaları

# %% [markdown]
# ## Hata analizi ve açıklanabilirlik

# %% [markdown]
# ## Nihai ensemble

# %% [markdown]
# ## Operasyonel kullanım ve sınırlamalar

# %% [markdown]
# ## Tekrar üretilebilirlik
